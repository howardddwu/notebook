# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/howardddwu/notebook/blob/main/Assignment2%20Hello%20Jypyter.ipynb)

# %%
from collections import Counter   
def anagram(first, second):        
  return Counter(first) == Counter(second)    

anagram("abcd3", "3acdb")
# Out:
# True

# %% [markdown]
# This code is when I dound Python super convient. Counter count the numebr of element in a iterable.

# %%
print(Counter("abcde"))
# Out:
# Counter({'a': 1, 'b': 1, 'c': 1, 'd': 1, 'e': 1})

# %% [markdown]
# Counter returns the count of diffenent element in a dictionary.
