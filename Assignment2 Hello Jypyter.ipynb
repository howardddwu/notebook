# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/howardddwu/notebook/blob/main/Assignment2%20Hello%20Jypyter.ipynb)

# %%
print("hello world")
# Out:
# hello world
